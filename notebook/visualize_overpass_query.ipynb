# %% [markdown]
# - [Overpass API](https://wiki.openstreetmap.org/wiki/JA:Overpass_API)
#
# - [Overpass Turbo](http://overpass-turbo.eu/)
#
# - [geocoding.jp](http://www.geocoding.jp/?q=%E9%83%BD%E5%BA%81)
#
# - [OSM taginfo](https://taginfo.openstreetmap.org/)

# %%
import dill
import overpy

# %%
with open('../script/data/2018421-amenity_fuel.pkl', 'rb') as f:
    result = dill.load(f)

# %%
len(result.nodes)
# Out:
# 8592

# %%
coord_list = []
for node in result.nodes:
#     print(node.tags)
    coord_list.append([node.lon, node.lat])

# %%
from bokeh.plotting import figure
from bokeh.io import show, output_file, output_notebook, push_notebook

lon = []
lat = []
for coord in coord_list:
    lon.append(coord[0])
    lat.append(coord[1])

plot = figure()
plot.grid.visible = False
plot.axis.visible = False
plot.circle(lon, lat, color='#4c4c4c', size=0.5)

output_notebook()
handle = show(plot, notebook_handle=True)
push_notebook(handle=handle)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8aef892b-7677-4fd7-9670-321bca973fbc">Loading BokehJS ...</span>
#     </div>
# /Users/nao/Python/env/overpass/lib/python3.6/site-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# <div class="bk-root">
#     <div class="bk-plotdiv" id="917c1628-fa9f-4feb-b5b1-a73f960da1a4"></div>
# </div>
